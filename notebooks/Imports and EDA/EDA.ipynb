# %%
import polars as pl
import bz2
import gzip as gz
import matplotlib.pyplot as plt
import numpy as np
import re
from collections import Counter

# %% [markdown]
# # KEY EDA to do
#
# Project will involeve the flows too and from each user and we will look at binning the flows.
#
# 1) Basic checks
#     Checks for duplicates number of source and destination computers, time window etc.
# 2) Frequency checks
#     Checks for the distributions of user sent and recieved signal activity, frequency by human and machine.
# 3) Do basic statistical tests for periodicity across users and in human and machine users. (randomly sample if necessary)
# 4) investigate the effects of binning
#
# list 2
# 1) Invesitgate the flows too and from each user how many go from each machine in a given time period.
# 2) Investigate variance of a machines flows over time.
# 3) Investigate the effect of binning width has on machine flow bias and variance.
# 4) Aim to indentify both human and machine operated accounts.
# 5) Static clustering
#
# #### Ideas
# - Idea smooth the distribution of mus towards the other distribution. I.e. for each user we will have a value of mu for each bin. Then for each cluster we will have an average distribution of mus. We will smooth the lower tail of the mu for a user towards the average lower tail obsered in that cluster. This way we preserve the periodic structure for each user whilst smoothing extremes.
# - Pick binning based on frequency periodicity analysis.
#
# #### Questions
# - How to bin
# - How to handle multiple requests within the same time period
# - How to handle low frequency users
# - How to smooth
# - How good is the human machine classification system I have seen human users exhibiting behaviour with high requests and periodicity that are often seen in machines is this just a normal upper tail human or a machine
# - Should I be dealing with users or computers
# - What are the anonymous logons in the dataset

# %% [markdown]
# ### Flows to and from each user and distribution of user flows

# %%
df = pl.scan_parquet("/home/ma/a/alb25/Project/thesis_code/data/*")

# %%
# Adding the user type columns
def user_type(user):
    if re.match(r"^U\d+@", user):
        return "human"
    if re.match(r"^C\d+\$@", user):
        return "machine"
    if re.match(r"^SYSTEM@", user):
        return "machine"
    if re.match(r"^LOCAL SERVICE@", user):
        return "machine"
    if re.match(r"^NETWORK SERVICE@", user):
        return "machine"
    if re.match(r"^ANONYMOUS LOGON@", user):
        return "anon"
    return "other"

df = df.with_columns(
    pl.col('source_user@domain').map_elements(user_type).alias('source_user_type'),
    pl.col('destination_user@domain').map_elements(user_type).alias('destination_user_type')
)

# %%
df.head().collect()
# Out:
# shape: (5, 11)
# ┌──────┬────────────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ time ┆ source_use ┆ destinatio ┆ source_com ┆ … ┆ authentica ┆ success/f ┆ source_us ┆ destinati │
# │ ---  ┆ r@domain   ┆ n_user@dom ┆ puter      ┆   ┆ tion_orien ┆ ailure    ┆ er_type   ┆ on_user_t │
# │ str  ┆ ---        ┆ ain        ┆ ---        ┆   ┆ tation     ┆ ---       ┆ ---       ┆ ype       │
# │      ┆ str        ┆ ---        ┆ str        ┆   ┆ ---        ┆ str       ┆ str       ┆ ---       │
# │      ┆            ┆ str        ┆            ┆   ┆ str        ┆           ┆           ┆ str       │
# ╞══════╪════════════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 1    ┆ ANONYMOUS  ┆ ANONYMOUS  ┆ C1250      ┆ … ┆ LogOn      ┆ Success   ┆ anon      ┆ anon      │
# │      ┆ LOGON@C586 ┆ LOGON@C586 ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 1    ┆ ANONYMOUS  ┆ ANONYMOUS  ┆ C586       ┆ … ┆ LogOff     ┆ Success   ┆ anon      ┆ anon      │
# │      ┆ LOGON@C586 ┆ LOGON@C586 ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 1    ┆ C101$@DOM1 ┆ C101$@DOM1 ┆ C988       ┆ … ┆ LogOff     ┆ Success   ┆ machine   ┆ machine   │
# │ 1    ┆ C1020$@DOM ┆ SYSTEM@C10 ┆ C1020      ┆ … ┆ LogOn      ┆ Success   ┆ machine   ┆ machine   │
# │      ┆ 1          ┆ 20         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 1    ┆ C1021$@DOM ┆ C1021$@DOM ┆ C1021      ┆ … ┆ LogOn      ┆ Success   ┆ machine   ┆ machine   │
# │      ┆ 1          ┆ 1          ┆            ┆   ┆            ┆           ┆           ┆           │
# └──────┴────────────┴────────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ## Basic Checks

# %%
destinations = df.select('destination_computer').unique().collect()['destination_computer'].to_list()

# %%
sources = df.select('source_computer').unique().collect()['source_computer'].to_list()

# %%
len(destinations)
# Out:
# 15620

# %%
len(sources)
# Out:
# 16006

# %%
df.head().collect()
# Out:
# shape: (5, 9)
# ┌──────┬────────────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ time ┆ source_use ┆ destinatio ┆ source_com ┆ … ┆ authentica ┆ logon_typ ┆ authentic ┆ success/f │
# │ ---  ┆ r@domain   ┆ n_user@dom ┆ puter      ┆   ┆ tion_type  ┆ e         ┆ ation_ori ┆ ailure    │
# │ str  ┆ ---        ┆ ain        ┆ ---        ┆   ┆ ---        ┆ ---       ┆ entation  ┆ ---       │
# │      ┆ str        ┆ ---        ┆ str        ┆   ┆ str        ┆ str       ┆ ---       ┆ str       │
# │      ┆            ┆ str        ┆            ┆   ┆            ┆           ┆ str       ┆           │
# ╞══════╪════════════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 1    ┆ ANONYMOUS  ┆ ANONYMOUS  ┆ C1250      ┆ … ┆ NTLM       ┆ Network   ┆ LogOn     ┆ Success   │
# │      ┆ LOGON@C586 ┆ LOGON@C586 ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 1    ┆ ANONYMOUS  ┆ ANONYMOUS  ┆ C586       ┆ … ┆ ?          ┆ Network   ┆ LogOff    ┆ Success   │
# │      ┆ LOGON@C586 ┆ LOGON@C586 ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 1    ┆ C101$@DOM1 ┆ C101$@DOM1 ┆ C988       ┆ … ┆ ?          ┆ Network   ┆ LogOff    ┆ Success   │
# │ 1    ┆ C1020$@DOM ┆ SYSTEM@C10 ┆ C1020      ┆ … ┆ Negotiate  ┆ Service   ┆ LogOn     ┆ Success   │
# │      ┆ 1          ┆ 20         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 1    ┆ C1021$@DOM ┆ C1021$@DOM ┆ C1021      ┆ … ┆ Kerberos   ┆ Network   ┆ LogOn     ┆ Success   │
# │      ┆ 1          ┆ 1          ┆            ┆   ┆            ┆           ┆           ┆           │
# └──────┴────────────┴────────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
df.select(
    pl.col('time').cast(pl.Int64).max().alias('max_time'),
    pl.col('time').cast(pl.Int64).min().alias('min_time'),
    ).collect()
# Out:
# shape: (1, 2)
# ┌──────────┬──────────┐
# │ max_time ┆ min_time │
# │ ---      ┆ ---      │
# │ i64      ┆ i64      │
# ╞══════════╪══════════╡
# │ 5011199  ┆ 1        │
# └──────────┴──────────┘

# %%
# We have 58 days of data
5011199 / (3600*24)
# Out:
# 57.99998842592593

# %%
cols = df.collect_schema().names()
df = df.with_columns(pl.struct(cols).hash(seed=0).alias('hash'))
df2 = df.select('hash').group_by('hash').len().top_k(by='len', k=5).head().collect()

# %%
# No duplicate rows found in the data
df2
# Out:
# shape: (5, 2)
# ┌──────────────────────┬─────┐
# │ hash                 ┆ len │
# │ ---                  ┆ --- │
# │ u64                  ┆ u32 │
# ╞══════════════════════╪═════╡
# │ 10489887825803446894 ┆ 1   │
# │ 10043600765358434665 ┆ 1   │
# │ 17312281700719399321 ┆ 1   │
# │ 7365033346672452035  ┆ 1   │
# │ 6629053896398302689  ┆ 1   │
# └──────────────────────┴─────┘

# %%
# Top authentication methods
top_auths = df.group_by('authentication_type').len().collect()
top_auths.sort(by='len', descending=True)
# Out:
# shape: (29, 2)
# ┌─────────────────────────────────┬───────────┐
# │ authentication_type             ┆ len       │
# │ ---                             ┆ ---       │
# │ str                             ┆ u32       │
# ╞═════════════════════════════════╪═══════════╡
# │ ?                               ┆ 529653766 │
# │ Kerberos                        ┆ 329665951 │
# │ NTLM                            ┆ 44959119  │
# │ Negotiate                       ┆ 44944631  │
# │ MICROSOFT_AUTHENTICATION_PACKA… ┆ 675033    │
# │ …                               ┆ …         │
# │ CygwinLsa                       ┆ 14        │
# │ MICROSOFT_AUTHENTICATION_       ┆ 5         │
# │ MICROSOFT_AUTHENTICATIO         ┆ 4         │
# │ N                               ┆ 1         │
# │ TivoliAP                        ┆ 1         │
# └─────────────────────────────────┴───────────┘

# %%
df.group_by('success/failure').len().collect()
# Out:
# shape: (2, 2)
# ┌─────────────────┬───────────┐
# │ success/failure ┆ len       │
# │ ---             ┆ ---       │
# │ str             ┆ u32       │
# ╞═════════════════╪═══════════╡
# │ Success         ┆ 938810236 │
# │ Fail            ┆ 11189764  │
# └─────────────────┴───────────┘

# %% [markdown]
# ## Frequency count check

# %% [markdown]
# Totals plots for computers sent and recieved
#
# ![Output plot](savedplots/source_counts.png)
# ![Output plot](savedplots/destination_counts.png)
#
# Human machine breakdown for computer sent and recieved
#
# ![Output plot](savedplots/computer_freq_sent.png)
# ![Output plot](savedplots/computer_freq_recieved.png)
#
#
# #### Frequencies by user

# %%
df.head().collect()
# Out:
# shape: (5, 11)
# ┌──────┬────────────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ time ┆ source_use ┆ destinatio ┆ source_com ┆ … ┆ authentica ┆ success/f ┆ human_sou ┆ human_des │
# │ ---  ┆ r@domain   ┆ n_user@dom ┆ puter      ┆   ┆ tion_orien ┆ ailure    ┆ rce       ┆ tination  │
# │ str  ┆ ---        ┆ ain        ┆ ---        ┆   ┆ tation     ┆ ---       ┆ ---       ┆ ---       │
# │      ┆ str        ┆ ---        ┆ str        ┆   ┆ ---        ┆ str       ┆ bool      ┆ bool      │
# │      ┆            ┆ str        ┆            ┆   ┆ str        ┆           ┆           ┆           │
# ╞══════╪════════════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 1    ┆ ANONYMOUS  ┆ ANONYMOUS  ┆ C1250      ┆ … ┆ LogOn      ┆ Success   ┆ true      ┆ true      │
# │      ┆ LOGON@C586 ┆ LOGON@C586 ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 1    ┆ ANONYMOUS  ┆ ANONYMOUS  ┆ C586       ┆ … ┆ LogOff     ┆ Success   ┆ true      ┆ true      │
# │      ┆ LOGON@C586 ┆ LOGON@C586 ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 1    ┆ C101$@DOM1 ┆ C101$@DOM1 ┆ C988       ┆ … ┆ LogOff     ┆ Success   ┆ false     ┆ false     │
# │ 1    ┆ C1020$@DOM ┆ SYSTEM@C10 ┆ C1020      ┆ … ┆ LogOn      ┆ Success   ┆ false     ┆ true      │
# │      ┆ 1          ┆ 20         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 1    ┆ C1021$@DOM ┆ C1021$@DOM ┆ C1021      ┆ … ┆ LogOn      ┆ Success   ┆ false     ┆ false     │
# │      ┆ 1          ┆ 1          ┆            ┆   ┆            ┆           ┆           ┆           │
# └──────┴────────────┴────────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
def counts_to_cdf(counts):
    frequencies = counts['len'].to_list()
    sorted_freqs = np.sort(frequencies)
    cdf = np.arange(1, len(sorted_freqs) + 1) / len(sorted_freqs)
    return sorted_freqs, cdf

def plot_counts(column):
    if column in ('source_computer', 'source_user@domain'):
        user_type_col = 'source_user_type'
        plt_title = 'Authentications requests sent'
    else:
        user_type_col = 'destination_user_type'
        plt_title = 'Authentication Requests Recieved'

    human_counts = df.filter(pl.col(user_type_col) == 'human'
                                ).group_by([column]).len().sort(by='len', descending=True).collect()
    machine_counts = df.filter(pl.col(user_type_col) == 'machine'
                                ).group_by([column]).len().sort(by='len', descending=True).collect()
    anon_counts = df.filter(pl.col(user_type_col) == 'anon'
                                ).group_by([column]).len().sort(by='len', descending=True).collect()
    human_sf, human_cdf = counts_to_cdf(human_counts)
    machine_sf, machine_cdf = counts_to_cdf(machine_counts)
    anon_sf, anon_cdf = counts_to_cdf(anon_counts)

    plt.figure(figsize=(10, 6))
    plt.title(plt_title)
    plt.xscale('log')
    plt.xlabel('frequency')
    plt.ylabel('prop_of_computers_below_that_frequency')
    plt.plot(human_sf, human_cdf, alpha=0.5, label='human')
    plt.plot(machine_sf, machine_cdf, alpha=0.5, label='machine')
    plt.plot(anon_sf, anon_cdf, alpha=0.5, label='anon')
    plt.legend()
    plt.show()

# %%
plot_counts(column='source_computer')

# %%
plot_counts(column='source_user@domain')

# %%
plot_counts(column='destination_computer')

# %%
plot_counts(column='destination_user@domain')

# %%
top_pct = source_counts.head(200)
frequencies = top_pct['len'].to_list()
plt.hist(frequencies, bins=50)
plt.title('top 200 (approx 1%) machines frequency of auth (sent)')
plt.xlabel('auth frequency')
plt.ylabel('number of machines')
plt.show()

# %%
top_pct = destination_counts.head(200)
frequencies = top_pct['len'].to_list()
plt.hist(frequencies, bins=50)
plt.title('top 200 (approx 1%) machines frequency of auth (recieved)')
plt.xlabel('auth frequency')
plt.ylabel('number of machines')
plt.show()

# %%
# 50 machines make up 46% of all source auth flows
source_counts = source_counts.with_columns((pl.col('len').cum_sum() / pl.col('len').sum() *100).alias('cumulative_pct'))
source_counts.head(50)
# Out:
# shape: (50, 3)
# ┌─────────────────┬──────────┬────────────────┐
# │ source_computer ┆ len      ┆ cumulative_pct │
# │ ---             ┆ ---      ┆ ---            │
# │ str             ┆ u32      ┆ f64            │
# ╞═════════════════╪══════════╪════════════════╡
# │ C586            ┆ 50630165 ┆ 5.329491       │
# │ C612            ┆ 35137579 ┆ 9.028184       │
# │ C529            ┆ 33847062 ┆ 12.591032      │
# │ C467            ┆ 33226389 ┆ 16.088547      │
# │ C625            ┆ 32983300 ┆ 19.560473      │
# │ …               ┆ …        ┆ …              │
# │ C1691           ┆ 1502911  ┆ 45.467105      │
# │ C1183           ┆ 1399748  ┆ 45.614447      │
# │ C2855           ┆ 1381941  ┆ 45.759914      │
# │ C368            ┆ 1339684  ┆ 45.900934      │
# │ C606            ┆ 1288936  ┆ 46.036611      │
# └─────────────────┴──────────┴────────────────┘

# %%
# Again 50 machines make up 80% of destination flows
destination_counts = destination_counts.with_columns((pl.col('len').cum_sum() / pl.col('len').sum() *100).alias('cumulative_pct'))
destination_counts.head(50)
# Out:
# shape: (50, 3)
# ┌──────────────────────┬───────────┬────────────────┐
# │ destination_computer ┆ len       ┆ cumulative_pct │
# │ ---                  ┆ ---       ┆ ---            │
# │ str                  ┆ u32       ┆ f64            │
# ╞══════════════════════╪═══════════╪════════════════╡
# │ C586                 ┆ 121232327 ┆ 11.530228      │
# │ C612                 ┆ 75369542  ┆ 18.698514      │
# │ C529                 ┆ 72674773  ┆ 25.610504      │
# │ C625                 ┆ 72161687  ┆ 32.473696      │
# │ C467                 ┆ 71962942  ┆ 39.317985      │
# │ …                    ┆ …         ┆ …              │
# │ C3034                ┆ 1405970   ┆ 80.163391      │
# │ C3443                ┆ 1396036   ┆ 80.296166      │
# │ C368                 ┆ 1228988   ┆ 80.413053      │
# │ C1581                ┆ 1133376   ┆ 80.520847      │
# │ C1487                ┆ 1119537   ┆ 80.627324      │
# └──────────────────────┴───────────┴────────────────┘

# %% [markdown]
# ### Human vs machine account identification

# %%
print(len(machine_users))
machine_users
# Out:
# 17586
# ['C17705$@DOM1',
#  'C25542$@DOM1',
#  'C14519$@?',
#  'C7652$@?',
#  'C24052$@C24052',
#  'C8986$@DOM1',
#  'C15606$@?',
#  'C8688$@DOM1',
#  'C19105$@DOM1',
#  'C2676$@DOM1',
#  'C2058$@DOM1',
#  'C7583$@DOM1',
#  'C14746$@DOM1',
#  'C19744$@DOM1',
#  'C21331$@DOM1',
#  'C22909$@?',
#  'C16249$@?',
#  'C3011$@DOM1',
#  'C20710$@DOM1',
#  'C14676$@DOM1',
#  'C5675$@DOM8',
#  'C25886$@DOM1',
#  'C1577$@DOM1',
#  'C2733$@?',
#  'C3097$@DOM1',
#  'C3307$@?',
#  'C17941$@DOM1',
#  'C14110$@DOM1',
#  'C4106$@DOM1',
#  'C12989$@DOM1',
#  'C11122$@DOM1',
#  'C482$@DOM1',
#  'C13492$@DOM1',
#  'C1761$@C1761',
#  'C24663$@?',
#  'C12059$@?',
#  'C26253$@?',
#  'C16061$@DOM1',
#  'C8255$@DOM1',
#  'C5325$@DOM1',
#  'C24788$@?',
#  'C3575$@DOM1',
#  'C15388$@DOM1',
#  'C877$@DOM1',
#  'C22811$@DOM1',
#  'C12234$@DOM1',
#  'C18244$@DOM1',
#  'C19970$@DOM1',
#  'C29$@DOM1',
#  'C14445$@DOM1',
#  'C1381$@DOM267',
#  'C25892$@DOM1',
#  'C14197$@DOM1',
#  'C22980$@?',
#  'C13838$@DOM1',
#  'C2278$@DOM1',
#  'C1361$@DOM1',
#  'C1548$@DOM1',
#  'C5983$@DOM1',
#  'C197$@DOM1',
#  'C21706$@?',
#  'C5139$@DOM1',
#  'C12675$@?',
#  'C15324$@?',
#  'C17761$@DOM1',
#  'C20168$@DOM1',
#  'C11598$@DOM1',
#  'C16050$@DOM1',
#  'C10839$@DOM1',
#  'C9154$@DOM1',
#  'C23335$@DOM1',
#  'C134$@?',
#  'C15386$@DOM1',
#  'C12766$@DOM1',
#  'C17674$@DOM1',
#  'C13593$@?',
#  'C17616$@DOM1',
#  'C14781$@DOM1',
#  'C23088$@DOM1',
#  'C15922$@DOM1',
#  'C9768$@DOM1',
#  'C637$@DOM1',
#  'C25105$@DOM1',
#  'C19572$@DOM1',
#  'C179$@?',
#  'C3352$@DOM1',
#  'C13836$@DOM1',
#  'C8880$@DOM1',
#  'C20002$@DOM1',
#  'C17055$@DOM1',
#  'C7982$@DOM1',
#  'C1354$@DOM1',
#  'C1038$@DOM1',
#  'C20039$@DOM1',
#  'C26950$@?',
#  'C12402$@DOM1',
#  'C24340$@DOM1',
#  'C7556$@DOM85',
#  'C21703$@DOM1',
#  'C9475$@DOM1',
#  'C12100$@DOM1',
#  'C23972$@?',
#  'C16871$@DOM1',
#  'C9705$@?',
#  'C9174$@?',
#  'C19204$@DOM1',
#  'C10626$@?',
#  'C1593$@DOM1',
#  'C20089$@DOM1',
#  'C11779$@DOM1',
#  'C13950$@DOM1',
#  'C16539$@DOM1',
#  'C672$@DOM1',
#  'C6961$@DOM1',
#  'C1671$@DOM1',
#  'C6161$@DOM1',
#  'C1821$@DOM1',
#  'C12036$@?',
#  'C25359$@DOM1',
#  'C13374$@?',
#  'C6889$@DOM1',
#  'C3949$@DOM1',
#  'C24932$@DOM1',
#  'C19067$@DOM1',
#  'C21052$@DOM1',
#  'C16647$@?',
#  'C26411$@DOM1',
#  'C23143$@DOM1',
#  'C13298$@DOM1',
#  'C344$@DOM1',
#  'C24101$@DOM1',
#  'C531$@DOM1',
#  'C13795$@DOM1',
#  'C27139$@DOM1',
#  'C18289$@DOM1',
#  'C4515$@DOM1',
#  'C21873$@?',
#  'C851$@DOM1',
#  'C58$@DOM1',
#  'C1668$@DOM1',
#  'C11094$@DOM1',
#  'C375$@DOM1',
#  'C14328$@?',
#  'C4876$@?',
#  'C26796$@DOM1',
#  'C1269$@DOM1',
#  'C8776$@?',
#  'C13974$@?',
#  'C2264$@DOM1',
#  'C6560$@DOM1',
#  'C4808$@DOM1',
#  'C20527$@DOM1',
#  'C8266$@DOM1',
#  'C14907$@DOM1',
#  'C19821$@DOM1',
#  'C20418$@?',
#  'C5273$@DOM1',
#  'C4822$@DOM1',
#  'C5685$@DOM7',
#  'C6871$@DOM1',
#  'C16722$@DOM1',
#  'C26750$@DOM1',
#  'C26844$@DOM1',
#  'C6763$@DOM1',
#  'C14915$@DOM1',
#  'C17528$@DOM1',
#  'C22144$@?',
#  'C823$@DOM1',
#  'C18202$@DOM1',
#  'C8468$@?',
#  'C6555$@DOM1',
#  'C20503$@?',
#  'C21897$@?',
#  'C2604$@DOM1',
#  'C26745$@DOM1',
#  'C18628$@?',
#  'C1652$@?',
#  'C25876$@DOM1',
#  'C10835$@DOM1',
#  'C2674$@DOM1',
#  'C6102$@DOM1',
#  'C7822$@DOM1',
#  'C11198$@DOM1',
#  'C17939$@?',
#  'C4716$@DOM1',
#  'C19647$@DOM1',
#  'C11605$@DOM1',
#  'C1647$@DOM1',
#  'C19593$@DOM1',
#  'C15988$@DOM1',
#  'C20624$@C20624',
#  'C8666$@DOM1',
#  'C2260$@?',
#  'C18375$@DOM1',
#  'C65$@?',
#  'C17899$@DOM1',
#  'C4537$@DOM1',
#  'C11394$@DOM1',
#  'C2292$@DOM1',
#  'C9040$@DOM1',
#  'C17998$@DOM1',
#  'C19643$@DOM1',
#  'C9132$@DOM1',
#  'C7050$@?',
#  'C21315$@?',
#  'C19803$@DOM1',
#  'C14177$@DOM1',
#  'C19261$@DOM1',
#  'C1856$@DOM1',
#  'C7466$@?',
#  'C16189$@DOM1',
#  'C20520$@DOM1',
#  'C5339$@DOM1',
#  'C18125$@?',
#  'C270$@DOM1',
#  'C18477$@DOM1',
#  'C21415$@DOM1',
#  'C6897$@DOM1',
#  'C3344$@DOM1',
#  'C18328$@?',
#  'C25596$@DOM1',
#  'C9020$@DOM1',
#  'C12391$@DOM1',
#  'C11656$@DOM1',
#  'C20693$@?',
#  'C21676$@DOM1',
#  'C12111$@DOM1',
#  'C1381$@?',
#  'C19620$@?',
#  'C3332$@DOM1',
#  'C18176$@DOM1',
#  'C3370$@DOM1',
#  'C14156$@?',
#  'C21008$@?',
#  'C1655$@DOM1',
#  'C14311$@DOM1',
#  'C9218$@DOM1',
#  'C20676$@DOM15',
#  'C20220$@DOM1',
#  'C9508$@?',
#  'C26494$@?',
#  'C2395$@DOM1',
#  'C25706$@?',
#  'C23192$@DOM1',
#  'C16621$@DOM1',
#  'C8217$@?',
#  'C7206$@DOM1',
#  'C13764$@DOM1',
#  'C2597$@DOM1',
#  'C12443$@DOM1',
#  'C23044$@DOM106',
#  'C25980$@DOM1',
#  'C16379$@?',
#  'C1384$@DOM1',
#  'C10825$@DOM1',
#  'C1923$@DOM1',
#  'C11870$@DOM1',
#  'C1377$@DOM1',
#  'C21288$@DOM1',
#  'C1878$@DOM1',
#  'C24047$@DOM1',
#  'C12129$@?',
#  'C13140$@?',
#  'C1679$@DOM1',
#  'C3785$@DOM1',
#  'C25729$@DOM1',
#  'C16574$@?',
#  'C22523$@DOM1',
#  'C11619$@DOM1',
#  'C999$@DOM1',
#  'C6066$@DOM1',
#  'C318$@DOM1',
#  'C21215$@DOM1',
#  'C6308$@?',
#  'C19094$@?',
#  'C22160$@?',
#  'C17633$@DOM1',
#  'C13494$@DOM1',
#  'C15042$@DOM1',
#  'C21558$@DOM1',
#  'C19284$@DOM1',
#  'C1502$@DOM1',
#  'C3589$@DOM1',
#  'C22532$@?',
#  'C24819$@DOM1',
#  'C7373$@DOM1',
#  'C11770$@DOM1',
#  'C5022$@DOM1',
#  'C19272$@DOM1',
#  'C18560$@DOM1',
#  'C20714$@DOM1',
#  'C8163$@DOM1',
#  'C18320$@DOM1',
#  'C14322$@?',
#  'C15434$@?',
#  'C13785$@DOM1',
#  'C16322$@?',
#  'C19764$@?',
#  'C19741$@DOM1',
#  'C26078$@DOM1',
#  'C24835$@?',
#  'C26953$@DOM276',
#  'C14256$@DOM1',
#  'C7970$@DOM1',
#  'C13680$@DOM1',
#  'C17016$@DOM1',
#  'C1574$@DOM1',
#  'C11501$@?',
#  'C9011$@DOM1',
#  'C8924$@DOM1',
#  'C10894$@DOM1',
#  'C16224$@?',
#  'C6429$@DOM1',
#  'C6922$@?',
#  'C24862$@?',
#  'C25748$@DOM1',
#  'C12074$@?',
#  'C18242$@DOM1',
#  'C22931$@?',
#  'C15362$@DOM1',
#  'C1243$@DOM1',
#  'C18892$@DOM1',
#  'C23737$@DOM1',
#  'C22555$@DOM1',
#  'C8565$@DOM1',
#  'C20608$@DOM1',
#  'C9835$@DOM1',
#  'C10397$@DOM1',
#  'C20614$@DOM1',
#  'C12463$@DOM1',
#  'C8829$@DOM1',
#  'C7217$@DOM1',
#  'C280$@DOM1',
#  'C5561$@DOM1',
#  'C1677$@DOM1',
#  'C7018$@DOM1',
#  'C16629$@DOM1',
#  'C17929$@DOM1',
#  'C656$@DOM1',
#  'C1302$@DOM1',
#  'C21955$@?',
#  'C4861$@?',
#  'C11783$@?',
#  'C10197$@DOM1',
#  'C13606$@DOM1',
#  'C10618$@?',
#  'C5649$@DOM1',
#  'C8322$@DOM1',
#  'C7641$@DOM1',
#  'C17583$@?',
#  'C22365$@DOM1',
#  'C200$@DOM1',
#  'C3697$@DOM1',
#  'C14202$@DOM1',
#  'C23033$@C23033',
#  'C336$@?',
#  'C18332$@DOM1',
#  'C9786$@DOM1',
#  'C17397$@DOM1',
#  'C18973$@DOM1',
#  'C20773$@?',
#  'C24074$@DOM1',
#  'C8707$@?',
#  'C18825$@DOM1',
#  'C6236$@DOM1',
#  'C13722$@?',
#  'C21744$@C21744',
#  'C7876$@DOM1',
#  'C16348$@?',
#  'C19587$@?',
#  'C5596$@DOM1',
#  'C24162$@?',
#  'C9833$@DOM1',
#  'C12702$@DOM1',
#  'C10648$@DOM1',
#  'C22283$@DOM1',
#  'C547$@DOM1',
#  'C19356$@?',
#  'C15112$@DOM1',
#  'C5504$@DOM1',
#  'C14757$@DOM1',
#  'C26846$@DOM1',
#  'C10020$@?',
#  'C5163$@DOM1',
#  'C10865$@DOM1',
#  'C17752$@DOM1',
#  'C6022$@DOM1',
#  'C13657$@DOM1',
#  'C21516$@?',
#  'C7119$@DOM1',
#  'C22233$@DOM1',
#  'C13625$@DOM1',
#  'C17956$@C17956',
#  'C20672$@DOM1',
#  'C2792$@?',
#  'C15410$@DOM1',
#  'C12430$@DOM1',
#  'C20353$@?',
#  'C20862$@?',
#  'C6967$@DOM1',
#  'C26204$@C26204',
#  'C20446$@DOM1',
#  'C1700$@DOM1',
#  'C10442$@?',
#  'C27017$@DOM1',
#  'C592$@DOM1',
#  'C7525$@DOM1',
#  'C3657$@DOM1',
#  'C22047$@DOM1',
#  'C12684$@DOM1',
#  'C1513$@DOM1',
#  'C863$@DOM1',
#  'C9397$@DOM1',
#  'C10193$@DOM1',
#  'C18967$@DOM1',
#  'C25402$@DOM1',
#  'C26985$@DOM1',
#  'C22280$@C22280',
#  'C17155$@?',
#  'C24261$@?',
#  'C4730$@DOM1',
#  'C21520$@DOM1',
#  'C10156$@DOM1',
#  'C3610$@DOM1',
#  'C17510$@?',
#  'C7164$@DOM1',
#  'C8100$@?',
#  'C18322$@DOM1',
#  'C6198$@DOM1',
#  'C12194$@DOM1',
#  'C23042$@DOM1',
#  'C7683$@DOM1',
#  'C6464$@DOM1',
#  'C18355$@DOM1',
#  'C10142$@?',
#  'C9287$@DOM1',
#  'C866$@DOM1',
#  'C20783$@DOM1',
#  'C7211$@DOM1',
#  'C15438$@DOM1',
#  'C9842$@DOM1',
#  'C22224$@DOM1',
#  'C10551$@DOM1',
#  'C11238$@?',
#  'C1378$@DOM1',
#  'C25058$@DOM1',
#  'C26904$@?',
#  'C8736$@DOM1',
#  'C15632$@DOM1',
#  'C243$@DOM3',
#  'C15200$@?',
#  'C4081$@DOM1',
#  'C17640$@DOM1',
#  'C19954$@?',
#  'C21476$@?',
#  'C12941$@?',
#  'C11278$@?',
#  'C15604$@DOM1',
#  'C3799$@DOM1',
#  'C11890$@?',
#  'C10486$@DOM1',
#  'C3435$@DOM1',
#  'C14696$@DOM1',
#  'C15020$@DOM1',
#  'C24734$@DOM1',
#  'C25297$@DOM1',
#  'C22830$@DOM1',
#  'C18074$@DOM1',
#  'C16199$@DOM1',
#  'C4827$@DOM1',
#  'C590$@DOM1',
#  'C5664$@DOM3',
#  'C1562$@DOM1',
#  'C14835$@DOM1',
#  'C3024$@DOM1',
#  'C17259$@DOM15',
#  'C759$@DOM1',
#  'C583$@DOM1',
#  'C14540$@DOM1',
#  'C6041$@DOM1',
#  'C18923$@DOM1',
#  'C11006$@DOM1',
#  'C3963$@DOM1',
#  'C20584$@?',
#  'C9125$@DOM1',
#  'C1399$@DOM1',
#  'C2794$@DOM1',
#  'C19217$@?',
#  'C22945$@DOM1',
#  'C26725$@DOM1',
#  'C25560$@C25560',
#  'C5377$@DOM1',
#  'C19102$@DOM1',
#  'C15897$@DOM1',
#  'C2135$@DOM1',
#  'C21488$@DOM1',
#  'C25173$@DOM1',
#  'C22378$@DOM1',
#  'C22380$@?',
#  'C6832$@?',
#  'C15366$@DOM1',
#  'C10856$@DOM1',
#  'C16911$@DOM1',
#  'C15475$@?',
#  'C6213$@DOM1',
#  'C14278$@DOM1',
#  'C19522$@?',
#  'C26708$@DOM1',
#  'C9110$@DOM1',
#  'C8385$@?',
#  'C21761$@C21761',
#  'C3100$@DOM1',
#  'C7964$@DOM1',
#  'C12013$@DOM1',
#  'C17622$@C17622',
#  'C17313$@?',
#  'C16841$@?',
#  'C10399$@DOM1',
#  'C169$@DOM1',
#  'C17982$@DOM1',
#  'C22097$@DOM1',
#  'C21993$@DOM1',
#  'C21199$@DOM1',
#  'C12628$@?',
#  'C12885$@DOM1',
#  'C22186$@DOM1',
#  'C10338$@DOM1',
#  'C1669$@DOM1',
#  'C20073$@DOM1',
#  'C718$@DOM1',
#  'C22001$@DOM1',
#  'C4396$@DOM1',
#  'C8951$@DOM1',
#  'C18323$@DOM1',
#  'C10089$@DOM1',
#  'C7893$@?',
#  'C5390$@?',
#  'C18351$@DOM1',
#  'C2246$@?',
#  'C2692$@?',
#  'C18747$@DOM1',
#  'C11893$@DOM1',
#  'C22119$@DOM1',
#  'C18106$@DOM1',
#  'C13216$@?',
#  'C16955$@DOM1',
#  'C19010$@DOM1',
#  'C8836$@DOM1',
#  'C14527$@?',
#  'C25470$@DOM1',
#  'C10878$@?',
#  'C14678$@DOM1',
#  'C18692$@DOM1',
#  'C19118$@DOM1',
#  'C15911$@?',
#  'C12069$@DOM1',
#  'C23699$@DOM1',
#  'C24622$@DOM1',
#  'C8139$@DOM1',
#  'C716$@DOM1',
#  'C7718$@?',
#  'C4278$@DOM1',
#  'C10514$@?',
#  'C11697$@DOM1',
#  'C14660$@DOM1',
#  'C9881$@DOM1',
#  'C23282$@DOM1',
#  'C7645$@?',
#  'C16739$@?',
#  'C6846$@DOM1',
#  'C26385$@DOM1',
#  'C2519$@DOM1',
#  'C24387$@DOM1',
#  'C17597$@DOM1',
#  'C19934$@DOM1',
#  'C13462$@DOM1',
#  'C20087$@DOM1',
#  'C20781$@DOM1',
#  'C13014$@DOM1',
#  'C24206$@DOM1',
#  'C6223$@DOM1',
#  'C19570$@DOM1',
#  'C8304$@DOM1',
#  'C694$@DOM1',
#  'C6449$@DOM1',
#  'C14040$@DOM1',
#  'C14848$@DOM1',
#  'C21804$@C21804',
#  'C12611$@?',
#  'C15713$@DOM1',
#  'C24186$@?',
#  'C19600$@DOM1',
#  'C25597$@DOM1',
#  'C11188$@?',
#  'C26136$@DOM1',
#  'C2819$@DOM1',
#  'C19797$@DOM1',
#  'C7683$@?',
#  'C14467$@DOM1',
#  'C18192$@DOM1',
#  'C20813$@?',
#  'C13214$@?',
#  'C2536$@DOM1',
#  'C25316$@?',
#  'C12143$@DOM1',
#  'C11576$@DOM1',
#  'C19737$@DOM1',
#  'C14194$@DOM1',
#  'C2021$@DOM1',
#  'C4370$@DOM1',
#  'C13807$@DOM1',
#  'C3637$@DOM1',
#  'C12630$@?',
#  'C18440$@DOM1',
#  'C24990$@C24990',
#  'C18209$@?',
#  'C19103$@DOM1',
#  'C1757$@DOM1',
#  'C1884$@DOM1',
#  'C12102$@DOM1',
#  'C955$@DOM1',
#  'C4051$@DOM1',
#  'C21692$@DOM1',
#  'C7740$@DOM1',
#  'C12397$@?',
#  'C315$@DOM1',
#  'C25724$@DOM1',
#  'C2591$@DOM1',
#  'C9653$@?',
#  'C2931$@DOM1',
#  'C12082$@DOM1',
#  'C24649$@DOM1',
#  'C3381$@DOM1',
#  'C13497$@DOM1',
#  'C17068$@DOM1',
#  'C8264$@DOM1',
#  'C907$@DOM1',
#  'C3178$@DOM1',
#  'C22899$@DOM1',
#  'C8262$@DOM1',
#  'C11362$@DOM1',
#  'C2938$@DOM1',
#  'C26999$@DOM1',
#  'C1663$@?',
#  'C19546$@?',
#  'C26570$@DOM1',
#  'C23259$@DOM1',
#  'C17197$@DOM1',
#  'C27039$@DOM1',
#  'C21322$@DOM1',
#  'C20046$@DOM1',
#  'C19211$@?',
#  'C12122$@?',
#  'C8272$@?',
#  'C21509$@?',
#  'C9935$@?',
#  'C22632$@DOM1',
#  'C22585$@DOM1',
#  'C15370$@DOM1',
#  'C19132$@?',
#  'C10183$@DOM1',
#  'C18004$@DOM1',
#  'C20754$@?',
#  'C19393$@DOM1',
#  'C6221$@?',
#  'C1257$@DOM1',
#  'C2055$@DOM1',
#  'C3822$@?',
#  'C7940$@DOM1',
#  'C799$@DOM1',
#  'C20919$@DOM1',
#  'C16561$@?',
#  'C8797$@DOM1',
#  'C1325$@DOM1',
#  'C15482$@DOM1',
#  'C4167$@DOM1',
#  'C6312$@DOM1',
#  'C18240$@DOM1',
#  'C18747$@?',
#  'C549$@DOM1',
#  'C21068$@DOM1',
#  'C19755$@?',
#  'C11039$@DOM1',
#  'C7073$@?',
#  'C17125$@DOM1',
#  'C21374$@?',
#  'C14431$@DOM1',
#  'C3842$@DOM1',
#  'C11837$@DOM1',
#  'C12766$@C12766',
#  'C20401$@?',
#  'C20044$@DOM1',
#  'C1872$@DOM1',
#  'C9806$@DOM1',
#  'C10801$@DOM1',
#  'C602$@DOM1',
#  'C19887$@DOM1',
#  'C12339$@?',
#  'C21190$@DOM1',
#  'C8052$@DOM1',
#  'C25138$@DOM1',
#  'C2441$@?',
#  'C3827$@DOM1',
#  'C2428$@DOM1',
#  'C1816$@DOM1',
#  'C11178$@?',
#  'C2248$@DOM1',
#  'C77$@DOM1',
#  'C11202$@DOM1',
#  'C17021$@DOM1',
#  'C13152$@DOM1',
#  'C19647$@?',
#  'C745$@DOM1',
#  'C22171$@DOM1',
#  'C7618$@?',
#  'C5109$@DOM1',
#  'C17903$@?',
#  'C5431$@DOM1',
#  'C10557$@DOM1',
#  'C26758$@DOM1',
#  'C14087$@DOM1',
#  'C23646$@DOM1',
#  'C26368$@C26368',
#  'C6513$@DOM1',
#  'C13294$@DOM1',
#  'C26054$@DOM1',
#  'C12040$@?',
#  'C7361$@?',
#  'C6681$@DOM1',
#  'C12125$@DOM1',
#  'C2024$@DOM1',
#  'C23425$@?',
#  'C20926$@DOM1',
#  'C25091$@DOM1',
#  'C22173$@?',
#  'C14569$@DOM1',
#  'C6947$@?',
#  'C21110$@DOM1',
#  'C16678$@DOM1',
#  'C7533$@DOM1',
#  'C14708$@DOM1',
#  'C6483$@DOM1',
#  'C14223$@DOM1',
#  'C650$@DOM1',
#  'C21392$@DOM15',
#  'C20933$@DOM1',
#  'C437$@?',
#  'C10199$@DOM1',
#  'C18959$@DOM1',
#  'C10805$@DOM1',
#  'C13316$@DOM1',
#  'C15007$@DOM1',
#  'C2796$@DOM1',
#  'C22431$@?',
#  'C9544$@DOM1',
#  'C26578$@DOM1',
#  'C7521$@DOM1',
#  'C3189$@DOM1',
#  'C25521$@DOM1',
#  'C23547$@DOM1',
#  'C17866$@DOM1',
#  'C16567$@DOM1',
#  'C16312$@DOM1',
#  'C1207$@DOM1',
#  'C668$@DOM1',
#  'C22174$@?',
#  'C25798$@?',
#  'C14729$@DOM1',
#  'C674$@DOM1',
#  'C22452$@DOM1',
#  'C13661$@DOM1',
#  'C26062$@DOM1',
#  'C22652$@DOM1',
#  'C1731$@DOM1',
#  'C56$@?',
#  'C8635$@DOM1',
#  'C18009$@DOM1',
#  'C21736$@DOM1',
#  'C21527$@DOM1',
#  'C20393$@DOM1',
#  'C25630$@DOM1',
#  'C21655$@?',
#  'C27016$@DOM1',
#  'C2927$@DOM1',
#  'C14937$@DOM1',
#  'C4657$@DOM1',
#  'C18471$@?',
#  'C5954$@?',
#  'C24664$@DOM1',
#  'C14036$@DOM1',
#  'C24400$@?',
#  'C25245$@DOM1',
#  'C571$@DOM1',
#  'C6801$@DOM1',
#  'C13097$@DOM1',
#  'C21002$@DOM1',
#  'C12996$@DOM1',
#  'C20144$@DOM1',
#  'C14206$@DOM1',
#  'C23159$@C23158',
#  'C1223$@DOM1',
#  'C741$@DOM1',
#  'C16488$@DOM1',
#  'C20207$@DOM1',
#  'C24871$@C24871',
#  'C570$@DOM1',
#  'C26494$@DOM1',
#  'C8728$@DOM1',
#  'C10301$@?',
#  'C19690$@DOM1',
#  'C8297$@DOM1',
#  'C2267$@DOM1',
#  'C23513$@DOM1',
#  'C17905$@DOM1',
#  'C25096$@DOM1',
#  'C2653$@DOM1',
#  'C20023$@DOM1',
#  'C17701$@?',
#  'C20269$@?',
#  'C15900$@DOM1',
#  'C15293$@DOM1',
#  'C16182$@DOM1',
#  'C14375$@DOM1',
#  'C14831$@DOM1',
#  'C21681$@DOM1',
#  'C235$@DOM1',
#  'C22277$@?',
#  'C10719$@DOM1',
#  'C20916$@?',
#  'C16505$@?',
#  'C26948$@?',
#  'C9888$@DOM1',
#  'C18743$@DOM1',
#  'C6087$@DOM1',
#  'C22626$@?',
#  'C26376$@DOM1',
#  'C10697$@DOM1',
#  'C9184$@DOM1',
#  'C20450$@DOM1',
#  'C10559$@DOM1',
#  'C22590$@DOM1',
#  'C8346$@?',
#  'C18688$@DOM1',
#  'C730$@DOM1',
#  'C13499$@?',
#  'C27048$@DOM1',
#  'C16369$@DOM1',
#  'C13929$@DOM1',
#  'C22020$@DOM1',
#  'C17415$@?',
#  'C5279$@DOM1',
#  'C1380$@DOM1',
#  'C16780$@DOM1',
#  'C17835$@DOM1',
#  'C753$@DOM1',
#  'C23270$@DOM1',
#  'C2624$@DOM1',
#  'C5857$@DOM1',
#  'C7115$@DOM1',
#  'C19721$@DOM1',
#  'C20980$@DOM1',
#  'C6909$@?',
#  'C25091$@?',
#  'C9195$@DOM1',
#  'C19088$@DOM1',
#  'C1079$@DOM1',
#  'C3312$@DOM1',
#  'C15865$@DOM1',
#  'C12080$@?',
#  'C24842$@DOM1',
#  'C24909$@DOM1',
#  'C26585$@DOM1',
#  'C25068$@C25068',
#  'C23658$@DOM1',
#  'C3722$@DOM1',
#  'C8609$@DOM1',
#  'C26228$@DOM1',
#  'C18283$@DOM1',
#  'C11617$@DOM1',
#  'C3973$@DOM1',
#  'C9814$@DOM1',
#  'C3746$@DOM1',
#  'C888$@DOM1',
#  'C4102$@DOM1',
#  'C8363$@?',
#  'C13105$@DOM1',
#  'C1761$@DOM1',
#  'C23536$@DOM1',
#  'C3421$@DOM3',
#  'C18448$@?',
#  'C26505$@DOM1',
#  'C653$@DOM1',
#  'C2769$@DOM1',
#  'C12726$@DOM1',
#  'C11652$@DOM1',
#  'C17437$@DOM1',
#  'C23140$@DOM1',
#  'C25976$@DOM1',
#  'C4474$@DOM1',
#  'C1552$@DOM1',
#  'C8921$@DOM1',
#  'C4618$@DOM1',
#  'C22207$@DOM1',
#  'C1372$@DOM1',
#  'C17129$@DOM1',
#  'C8462$@DOM1',
#  'C12775$@DOM1',
#  'C6631$@DOM1',
#  'C23286$@DOM1',
#  'C23446$@DOM1',
#  'C11184$@DOM1',
#  'C11813$@DOM1',
#  'C23467$@?',
#  'C2378$@DOM1',
#  'C2588$@DOM1',
#  'C12135$@?',
#  'C10269$@DOM1',
#  'C9485$@DOM1',
#  'C14617$@DOM1',
#  'C7503$@DOM1',
#  'C25519$@DOM1',
#  'C1496$@DOM1',
#  'C11132$@DOM1',
#  'C18294$@?',
#  'C22585$@C22585',
#  'C17392$@DOM1',
#  'C20015$@DOM1',
#  'C7365$@DOM1',
#  'C8276$@DOM1',
#  'C21339$@?',
#  'C9172$@DOM1',
#  'C2540$@DOM1',
#  'C26771$@DOM1',
#  'C14317$@DOM1',
#  'C12036$@DOM1',
#  'C19402$@DOM1',
#  'C21000$@DOM1',
#  'C239$@DOM1',
#  'C13532$@DOM1',
#  'C19038$@DOM1',
#  'C21256$@DOM1',
#  'C9228$@DOM1',
#  'C6885$@DOM1',
#  'C16580$@DOM1',
#  'C16825$@?',
#  'C27167$@DOM1',
#  'C6423$@DOM1',
#  'C2082$@DOM1',
#  'C20785$@?',
#  'C7599$@DOM1',
#  'C7800$@?',
#  'C23854$@DOM1',
#  'C3120$@DOM1',
#  'C1204$@DOM1',
#  'C23829$@DOM1',
#  'C5457$@DOM1',
#  'C19676$@?',
#  'C14182$@DOM1',
#  'C23617$@DOM1',
#  'C8567$@?',
#  'C5129$@DOM1',
#  'C8546$@?',
#  'C1490$@DOM1',
#  'C21900$@DOM1',
#  'C9425$@DOM1',
#  'C10640$@DOM1',
#  'C1693$@?',
#  'C3816$@DOM1',
#  'C7413$@DOM1',
#  'C20638$@DOM1',
#  'C22918$@?',
#  'C11906$@?',
#  'C18759$@?',
#  'C19419$@DOM1',
#  'C18498$@DOM1',
#  'C3219$@DOM1',
#  'C6179$@DOM1',
#  'C2403$@DOM1',
#  'C7102$@DOM1',
#  'C14800$@DOM1',
#  'C10275$@DOM1',
#  'C22594$@DOM1',
#  'C1410$@?',
#  'C20061$@?',
#  'C14868$@DOM1',
#  'C1$@DOM1',
#  'C1328$@DOM1',
#  'C18113$@DOM1',
#  'C17202$@DOM1',
#  'C10010$@?',
#  'C20069$@DOM1',
#  'C21476$@DOM1',
#  'C5977$@DOM1',
#  'C26628$@DOM1',
#  'C13356$@DOM1',
#  'C19869$@DOM1',
#  'C1406$@DOM1',
#  'C7356$@DOM1',
#  'C7541$@DOM1',
#  'C26802$@DOM1',
#  ...]

# %%
print(len(human_users))
human_users
# Out:
# 62967
# ['U5582@DOM9',
#  'SYSTEM@C6874',
#  'SYSTEM@C11656',
#  'U2227@DOM1',
#  'U637@?',
#  'U10137@DOM1',
#  'LOCAL SERVICE@C23005',
#  'U10295@?',
#  'ANONYMOUS LOGON@C23306',
#  'U376@DOM9',
#  'U10658@DOM1',
#  'U5862@DOM1',
#  'U10696@DOM1',
#  'U6260@DOM9',
#  'U11891@DOM1',
#  'LOCAL SERVICE@C15558',
#  'SYSTEM@C18469',
#  'ANONYMOUS LOGON@C26498',
#  'U7963@?',
#  'U9421@?',
#  'ANONYMOUS LOGON@C3019',
#  'LOCAL SERVICE@C5771',
#  'U805@?',
#  'ANONYMOUS LOGON@C10888',
#  'U2321@DOM1',
#  'U8849@C22031',
#  'U6177@DOM21',
#  'NETWORK SERVICE@C5855',
#  'SYSTEM@C22220',
#  'U8693@?',
#  'U5666@DOM9',
#  'U6619@DOM1',
#  'U11288@?',
#  'SYSTEM@C19930',
#  'U12389@DOM1',
#  'U1463@DOM1',
#  'U8763@DOM1',
#  'SYSTEM@C23783',
#  'U1006@DOM1',
#  'ANONYMOUS LOGON@C11059',
#  'U8818@DOM1',
#  'U3233@?',
#  'U4330@DOM9',
#  'U4448@DOM1',
#  'SYSTEM@C20013',
#  'U7465@DOM9',
#  'U5065@DOM1',
#  'NETWORK SERVICE@C3974',
#  'SYSTEM@C10616',
#  'U9855@?',
#  'U1375@DOM1',
#  'SYSTEM@C15032',
#  'U2415@?',
#  'ANONYMOUS LOGON@C24071',
#  'U4476@?',
#  'U2921@?',
#  'SYSTEM@C14891',
#  'U10724@DOM9',
#  'U5065@DOM21',
#  'SYSTEM@C13014',
#  'SYSTEM@C18381',
#  'NETWORK SERVICE@C3921',
#  'U2819@DOM1',
#  'U5102@DOM1',
#  'NETWORK SERVICE@C23758',
#  'U6521@lanl.gov',
#  'U8158@DOM1',
#  'U9637@DOM21',
#  'U9591@C12699',
#  'U12082@DOM9',
#  'U9648@DOM1',
#  'U7785@DOM1',
#  'ANONYMOUS LOGON@C16911',
#  'ANONYMOUS LOGON@C8464',
#  'U1066@DOM1',
#  'LOCAL SERVICE@C1962',
#  'ANONYMOUS LOGON@C10730',
#  'U4415@?',
#  'ANONYMOUS LOGON@C26012',
#  'U4751@DOM1',
#  'NETWORK SERVICE@C19361',
#  'ANONYMOUS LOGON@C2570',
#  'U3938@DOM1',
#  'U11966@DOM1',
#  'U1110@?',
#  'U5258@DOM1',
#  'U4813@DOM9',
#  'U1718@DOM69',
#  'U5414@DOM1',
#  'ANONYMOUS LOGON@C20742',
#  'SYSTEM@C21209',
#  'U541@DOM1',
#  'SYSTEM@C22317',
#  'ANONYMOUS LOGON@C17139',
#  'U11178@DOM175',
#  'SYSTEM@C14835',
#  'SYSTEM@C12770',
#  'ANONYMOUS LOGON@C478',
#  'NETWORK SERVICE@C9875',
#  'LOCAL SERVICE@C18817',
#  'U5296@?',
#  'SYSTEM@C17779',
#  'SYSTEM@C2537',
#  'U223@DOM1',
#  'SYSTEM@C8653',
#  'U2373@DOM1',
#  'ANONYMOUS LOGON@C20491',
#  'U10032@C3131',
#  'U9164@?',
#  'ANONYMOUS LOGON@C8310',
#  'U579@DOM21',
#  'U628@?',
#  'U859@DOM9',
#  'SYSTEM@C20080',
#  'LOCAL SERVICE@C1893',
#  'U1718@C25855',
#  'U7772@DOM9',
#  'U1719@DOM21',
#  'U12393@DOM1',
#  'U7475@?',
#  'LOCAL SERVICE@C1761',
#  'U10374@DOM4',
#  'U3329@DOM21',
#  'SYSTEM@C18702',
#  'ANONYMOUS LOGON@C7732',
#  'NETWORK SERVICE@C10095',
#  'LOCAL SERVICE@C13857',
#  'U11059@DOM1',
#  'SYSTEM@C9912',
#  'SYSTEM@C6675',
#  'ANONYMOUS LOGON@C7254',
#  'U2587@DOM1',
#  'SYSTEM@C9473',
#  'SYSTEM@C6795',
#  'U1146@?',
#  'NETWORK SERVICE@C4657',
#  'ANONYMOUS LOGON@C19286',
#  'SYSTEM@C811',
#  'SYSTEM@C776',
#  'U11706@C23697',
#  'SYSTEM@C409',
#  'U7745@DOM1',
#  'LOCAL SERVICE@C3582',
#  'U7016@DOM1',
#  'SYSTEM@C16770',
#  'U8870@?',
#  'SYSTEM@C19972',
#  'U1222@DOM9',
#  'SYSTEM@C19151',
#  'U1459@?',
#  'LOCAL SERVICE@C5018',
#  'U3153@?',
#  'U9712@DOM9',
#  'LOCAL SERVICE@C21564',
#  'U7363@C2389',
#  'ANONYMOUS LOGON@C24863',
#  'U7539@DOM1',
#  'SYSTEM@C3200',
#  'ANONYMOUS LOGON@C1730',
#  'ANONYMOUS LOGON@C510',
#  'U7898@C22298',
#  'U12059@DOM1',
#  'SYSTEM@C6375',
#  'ANONYMOUS LOGON@C10014',
#  'ANONYMOUS LOGON@C2997',
#  'SYSTEM@C8696',
#  'U7594@DOM1',
#  'LOCAL SERVICE@C16247',
#  'SYSTEM@C19204',
#  'U6761@?',
#  'SYSTEM@C12594',
#  'SYSTEM@C7568',
#  'U7887@DOM1',
#  'U3095@DOM1',
#  'LOCAL SERVICE@C21970',
#  'U11265@DOM1',
#  'LOCAL SERVICE@C5043',
#  'SYSTEM@C607',
#  'NETWORK SERVICE@C24683',
#  'ANONYMOUS LOGON@C22024',
#  'SYSTEM@C7660',
#  'LOCAL SERVICE@C9888',
#  'LOCAL SERVICE@C16023',
#  'U1837@C4208',
#  'NETWORK SERVICE@C11684',
#  'LOCAL SERVICE@C20824',
#  'U3333@DOM9',
#  'U4992@?',
#  'LOCAL SERVICE@C20931',
#  'U2080@DOM1',
#  'U11286@?',
#  'LOCAL SERVICE@C9373',
#  'LOCAL SERVICE@C9195',
#  'NETWORK SERVICE@C4497',
#  'LOCAL SERVICE@C20710',
#  'U3076@?',
#  'LOCAL SERVICE@C15964',
#  'ANONYMOUS LOGON@C22104',
#  'U9028@DOM21',
#  'U5081@DOM92',
#  'SYSTEM@C1231',
#  'LOCAL SERVICE@C8149',
#  'U11102@DOM1',
#  'U3787@DOM1',
#  'U4213@DOM1',
#  'LOCAL SERVICE@C19626',
#  'NETWORK SERVICE@C3042',
#  'U7363@C3524',
#  'SYSTEM@C3422',
#  'SYSTEM@C12729',
#  'ANONYMOUS LOGON@C20785',
#  'U550@C15522',
#  'ANONYMOUS LOGON@C81',
#  'SYSTEM@C21141',
#  'ANONYMOUS LOGON@C23854',
#  'U1509@?',
#  'ANONYMOUS LOGON@C7898',
#  'U7477@DOM1',
#  'U9217@?',
#  'U10516@?',
#  'ANONYMOUS LOGON@C10173',
#  'NETWORK SERVICE@C12958',
#  'ANONYMOUS LOGON@C12618',
#  'ANONYMOUS LOGON@C15077',
#  'U2896@?',
#  'ANONYMOUS LOGON@C12766',
#  'NETWORK SERVICE@C18087',
#  'U9595@DOM1',
#  'U1182@?',
#  'U7066@?',
#  'ANONYMOUS LOGON@C4429',
#  'ANONYMOUS LOGON@C7703',
#  'ANONYMOUS LOGON@C20813',
#  'ANONYMOUS LOGON@C4347',
#  'U2201@DOM1',
#  'U1173@DOM1',
#  'ANONYMOUS LOGON@C16598',
#  'NETWORK SERVICE@C11278',
#  'SYSTEM@C1759',
#  'SYSTEM@C20542',
#  'NETWORK SERVICE@C10041',
#  'ANONYMOUS LOGON@C13439',
#  'SYSTEM@C2957',
#  'SYSTEM@C18680',
#  'ANONYMOUS LOGON@C16438',
#  'U10726@DOM9',
#  'ANONYMOUS LOGON@C11574',
#  'U10789@?',
#  'U12326@DOM9',
#  'U4178@DOM9',
#  'U1515@?',
#  'ANONYMOUS LOGON@C12661',
#  'ANONYMOUS LOGON@C9046',
#  'SYSTEM@C15410',
#  'U8620@?',
#  'ANONYMOUS LOGON@C26591',
#  'U2614@DOM1',
#  'SYSTEM@C12046',
#  'SYSTEM@C11219',
#  'U11042@DOM9',
#  'U2128@DOM1',
#  'SYSTEM@C3745',
#  'ANONYMOUS LOGON@C12642',
#  'SYSTEM@C20267',
#  'U4182@?',
#  'U7257@DOM9',
#  'U1692@DOM1',
#  'U1820@DOM1',
#  'U281@DOM3',
#  'ANONYMOUS LOGON@C26854',
#  'U11412@C2827',
#  'SYSTEM@C6012',
#  'U9522@DOM1',
#  'ANONYMOUS LOGON@C6649',
#  'LOCAL SERVICE@C10799',
#  'SYSTEM@C19908',
#  'ANONYMOUS LOGON@C16354',
#  'LOCAL SERVICE@C14464',
#  'NETWORK SERVICE@C18668',
#  'ANONYMOUS LOGON@C11029',
#  'SYSTEM@C19350',
#  'SYSTEM@C10230',
#  'ANONYMOUS LOGON@C922',
#  'SYSTEM@C26260',
#  'U9937@DOM1',
#  'SYSTEM@C20283',
#  'U3579@DOM1',
#  'ANONYMOUS LOGON@C1665',
#  'U8378@?',
#  'U132@DOM1',
#  'U6669@DOM9',
#  'SYSTEM@C14501',
#  'U2827@DOM21',
#  'U1139@DOM9',
#  'SYSTEM@C11796',
#  'U7333@?',
#  'U11395@?',
#  'ANONYMOUS LOGON@C665',
#  'U3778@?',
#  'U8964@DOM1',
#  'U10744@DOM1',
#  'SYSTEM@C19797',
#  'LOCAL SERVICE@C4352',
#  'ANONYMOUS LOGON@C9982',
#  'NETWORK SERVICE@C1843',
#  'U1352@DOM1',
#  'U1718@C23820',
#  'NETWORK SERVICE@C5671',
#  'SYSTEM@C9795',
#  'U5274@DOM1',
#  'U1488@?',
#  'U5448@DOM1',
#  'SYSTEM@C11587',
#  'SYSTEM@C16424',
#  'ANONYMOUS LOGON@C22014',
#  'SYSTEM@C3210',
#  'U10849@DOM1',
#  'U1718@C5020',
#  'U7758@?',
#  'SYSTEM@C3183',
#  'SYSTEM@C19202',
#  'U9521@DOM1',
#  'U4923@?',
#  'SYSTEM@C3983',
#  'SYSTEM@C21152',
#  'ANONYMOUS LOGON@C15787',
#  'SYSTEM@C17107',
#  'U217@DOM1',
#  'ANONYMOUS LOGON@C444',
#  'SYSTEM@C7139',
#  'U5455@DOM9',
#  'ANONYMOUS LOGON@C24730',
#  'U7664@C911',
#  'U146@?',
#  'U7683@DOM9',
#  'U3209@?',
#  'ANONYMOUS LOGON@C352',
#  'U149@DOM1',
#  'SYSTEM@C11510',
#  'U11332@?',
#  'U11339@DOM1',
#  'U1718@C27160',
#  'ANONYMOUS LOGON@C11770',
#  'U10276@DOM1',
#  'SYSTEM@C196',
#  'ANONYMOUS LOGON@C7404',
#  'U7363@C4195',
#  'U2161@?',
#  'U8865@?',
#  'U408@DOM1',
#  'NETWORK SERVICE@C16583',
#  'U2824@DOM1',
#  'SYSTEM@C521',
#  'U3488@?',
#  'U10345@?',
#  'U7874@C17122',
#  'U656@C22762',
#  'U357@C36',
#  'U3452@DOM1',
#  'U2348@?',
#  'ANONYMOUS LOGON@C3827',
#  'U5255@DOM1',
#  'U12372@DOM1',
#  'LOCAL SERVICE@C7850',
#  'ANONYMOUS LOGON@C3300',
#  'U7562@?',
#  'ANONYMOUS LOGON@C11215',
#  'ANONYMOUS LOGON@C12318',
#  'SYSTEM@C7656',
#  'U4158@DOM1',
#  'SYSTEM@C11697',
#  'LOCAL SERVICE@C13070',
#  'U8102@?',
#  'NETWORK SERVICE@C22899',
#  'U1792@DOM1',
#  'ANONYMOUS LOGON@C22631',
#  'NETWORK SERVICE@C4444',
#  'SYSTEM@C1929',
#  'U10543@?',
#  'U10588@DOM9',
#  'NETWORK SERVICE@C20498',
#  'NETWORK SERVICE@C20783',
#  'NETWORK SERVICE@C6201',
#  'ANONYMOUS LOGON@C6661',
#  'SYSTEM@C7597',
#  'LOCAL SERVICE@C11934',
#  'U3853@DOM1',
#  'ANONYMOUS LOGON@C2653',
#  'SYSTEM@C6435',
#  'ANONYMOUS LOGON@C10077',
#  'U2937@?',
#  'ANONYMOUS LOGON@C7978',
#  'LOCAL SERVICE@C22124',
#  'SYSTEM@C24746',
#  'U1333@DOM9',
#  'SYSTEM@C26349',
#  'U7717@DOM9',
#  'SYSTEM@C16060',
#  'U1718@C25549',
#  'U2164@DOM9',
#  'U9203@DOM1',
#  'SYSTEM@C1504',
#  'SYSTEM@C10378',
#  'U6192@?',
#  'ANONYMOUS LOGON@C13608',
#  'U5316@DOM3',
#  'U7611@?',
#  'U11106@?',
#  'U8328@DOM9',
#  'NETWORK SERVICE@C9030',
#  'ANONYMOUS LOGON@C5618',
#  'SYSTEM@C15064',
#  'U4171@?',
#  'ANONYMOUS LOGON@C2047',
#  'U4726@?',
#  'U11569@DOM1',
#  'SYSTEM@C14724',
#  'U2448@?',
#  'U2861@DOM1',
#  'ANONYMOUS LOGON@C3415',
#  'U3568@wn',
#  'SYSTEM@C14143',
#  'SYSTEM@C18248',
#  'U11916@DOM1',
#  'U1178@DOM9',
#  'LOCAL SERVICE@C4907',
#  'U442@DOM21',
#  'SYSTEM@C1074',
#  'SYSTEM@C26127',
#  'ANONYMOUS LOGON@C6318',
#  'LOCAL SERVICE@C6437',
#  'U3767@DOM40',
#  'U11719@DOM1',
#  'ANONYMOUS LOGON@C20438',
#  'U8077@?',
#  'U8996@DOM1',
#  'SYSTEM@C934',
#  'LOCAL SERVICE@C22409',
#  'SYSTEM@C13821',
#  'U11056@DOM1',
#  'U1718@C24027',
#  'U1020@DOM9',
#  'SYSTEM@C14934',
#  'U6502@DOM1',
#  'NETWORK SERVICE@C7442',
#  'SYSTEM@C8126',
#  'SYSTEM@C16691',
#  'U5077@?',
#  'U9308@DOM1',
#  'LOCAL SERVICE@C14200',
#  'LOCAL SERVICE@C18191',
#  'SYSTEM@C5181',
#  'U10984@DOM1',
#  'U11918@?',
#  'U1964@?',
#  'ANONYMOUS LOGON@C6743',
#  'ANONYMOUS LOGON@C8893',
#  'SYSTEM@C10351',
#  'U5969@?',
#  'ANONYMOUS LOGON@C16553',
#  'U10171@DOM1',
#  'SYSTEM@C14200',
#  'SYSTEM@C2870',
#  'U1370@DOM1',
#  'U8669@DOM1',
#  'U6597@DOM9',
#  'U10017@DOM1',
#  'SYSTEM@C24426',
#  'U5767@DOM1',
#  'U1336@DOM1',
#  'U3289@DOM21',
#  'SYSTEM@C16516',
#  'U6437@DOM1',
#  'U9225@DOM9',
#  'U4424@DOM1',
#  'SYSTEM@C1168',
#  'U2424@DOM1',
#  'SYSTEM@C1315',
#  'NETWORK SERVICE@C18377',
#  'SYSTEM@C4581',
#  'U3347@DOM1',
#  'ANONYMOUS LOGON@C1232',
#  'U6793@DOM1',
#  'U1720@C19012',
#  'U7363@C1929',
#  'ANONYMOUS LOGON@C12050',
#  'U10595@DOM1',
#  'SYSTEM@C25495',
#  'NETWORK SERVICE@C4345',
#  'U10885@lanal.gov',
#  'NETWORK SERVICE@C23226',
#  'U4235@?',
#  'SYSTEM@C14642',
#  'SYSTEM@C3305',
#  'NETWORK SERVICE@C17155',
#  'U5179@?',
#  'U12209@?',
#  'LOCAL SERVICE@C16856',
#  'U1718@C21484',
#  'ANONYMOUS LOGON@C20429',
#  'ANONYMOUS LOGON@C8045',
#  'U8451@DOM1',
#  'SYSTEM@C4541',
#  'U8985@?',
#  'SYSTEM@C4535',
#  'U7211@DOM9',
#  'U2618@DOM1',
#  'U1986@C16490',
#  'ANONYMOUS LOGON@C17857',
#  'LOCAL SERVICE@C22179',
#  'SYSTEM@C18540',
#  'U2301@?',
#  'LOCAL SERVICE@C3484',
#  'NETWORK SERVICE@C3320',
#  'ANONYMOUS LOGON@C18535',
#  'U4688@DOM3',
#  'ANONYMOUS LOGON@C1010',
#  'U9624@DOM1',
#  'SYSTEM@C6474',
#  'U4797@DOM1',
#  'SYSTEM@C6091',
#  'U5453@DOM1',
#  'U7930@DOM1',
#  'SYSTEM@C1118',
#  'U11019@C23038',
#  'U11307@DOM9',
#  'U7363@C4398',
#  'U8821@DOM1',
#  'NETWORK SERVICE@C3334',
#  'LOCAL SERVICE@C21553',
#  'SYSTEM@C19719',
#  'U9469@?',
#  'U5282@DOM9',
#  'SYSTEM@C24186',
#  'U1718@C7198',
#  'SYSTEM@C23094',
#  'U3130@DOM1',
#  'U1718@C13715',
#  'SYSTEM@C8921',
#  'ANONYMOUS LOGON@C26672',
#  'U2914@?',
#  'SYSTEM@C2989',
#  'U11803@DOM1',
#  'ANONYMOUS LOGON@C10394',
#  'U8678@?',
#  'U3492@DOM1',
#  'U4078@?',
#  'U5490@DOM1',
#  'U357@C231',
#  'U11614@DOM1',
#  'U9602@?',
#  'ANONYMOUS LOGON@C3910',
#  'SYSTEM@C1289',
#  'ANONYMOUS LOGON@C16629',
#  'ANONYMOUS LOGON@C16709',
#  'SYSTEM@C4992',
#  'U7363@C4310',
#  'U1718@C14182',
#  'ANONYMOUS LOGON@C5931',
#  'U9205@DOM1',
#  'ANONYMOUS LOGON@C21683',
#  'U463@?',
#  'U6662@?',
#  'U35@C1759',
#  'LOCAL SERVICE@C8392',
#  'U9170@?',
#  'ANONYMOUS LOGON@C2607',
#  'U6896@C140',
#  'LOCAL SERVICE@C14102',
#  'U6242@C1455',
#  'ANONYMOUS LOGON@C7828',
#  'ANONYMOUS LOGON@C25486',
#  'SYSTEM@C22961',
#  'SYSTEM@C15060',
#  'NETWORK SERVICE@C21429',
#  'ANONYMOUS LOGON@C1569',
#  'SYSTEM@C11789',
#  'LOCAL SERVICE@C7592',
#  'ANONYMOUS LOGON@C2235',
#  'U4020@?',
#  'SYSTEM@C19067',
#  'SYSTEM@C19354',
#  'SYSTEM@C18607',
#  'U4453@DOM1',
#  'U7050@?',
#  'U6323@C2390',
#  'U8988@DOM1',
#  'U6295@?',
#  'SYSTEM@C1055',
#  'ANONYMOUS LOGON@C4953',
#  'SYSTEM@C721',
#  'LOCAL SERVICE@C7497',
#  'SYSTEM@C1849',
#  'SYSTEM@C15372',
#  'ANONYMOUS LOGON@C22224',
#  'U5508@?',
#  'U3593@DOM1',
#  'U9291@DOM9',
#  'ANONYMOUS LOGON@C4345',
#  'U8127@DOM1',
#  'LOCAL SERVICE@C24452',
#  'U6676@?',
#  'ANONYMOUS LOGON@C10003',
#  'U4775@?',
#  'U1823@?',
#  'U2719@DOM1',
#  'U8322@DOM9',
#  'ANONYMOUS LOGON@C5030',
#  'U449@DOM1',
#  'U7363@C3147',
#  'SYSTEM@C1808',
#  'U2337@?',
#  'U2798@DOM1',
#  'U4653@DOM1',
#  'SYSTEM@C1160',
#  'U5384@?',
#  'U4954@?',
#  'U8317@?',
#  'ANONYMOUS LOGON@C6485',
#  'NETWORK SERVICE@C3089',
#  'U3374@DOM1',
#  'U6506@?',
#  'U10726@DOM1',
#  'LOCAL SERVICE@C1152',
#  'ANONYMOUS LOGON@C20114',
#  'U1048@?',
#  'ANONYMOUS LOGON@C6853',
#  'U10275@DOM9',
#  'U5594@?',
#  'ANONYMOUS LOGON@C145',
#  'SYSTEM@C13817',
#  'SYSTEM@C17598',
#  'ANONYMOUS LOGON@C12120',
#  'ANONYMOUS LOGON@C4372',
#  'U11414@DOM1',
#  'U5966@?',
#  'U7993@DOM1',
#  'ANONYMOUS LOGON@C4879',
#  'ANONYMOUS LOGON@C25508',
#  'U6505@DOM9',
#  'U12399@DOM1',
#  'NETWORK SERVICE@C1747',
#  'SYSTEM@C9818',
#  'ANONYMOUS LOGON@C16230',
#  'U6758@DOM1',
#  'ANONYMOUS LOGON@C16926',
#  'ANONYMOUS LOGON@C4144',
#  'SYSTEM@C10134',
#  'U8162@DOM1',
#  'ANONYMOUS LOGON@C80',
#  'U203@DOM9',
#  'U5278@?',
#  'U4817@DOM1',
#  'U6989@DOM1',
#  'U7392@DOM1',
#  'U11568@?',
#  'U435@DOM1',
#  'NETWORK SERVICE@C17933',
#  'U3729@DOM9',
#  'ANONYMOUS LOGON@C10825',
#  'SYSTEM@C2594',
#  'SYSTEM@C7792',
#  'U12277@?',
#  'U2237@DOM1',
#  'SYSTEM@C10656',
#  'U5007@?',
#  'SYSTEM@C25131',
#  'SYSTEM@C9357',
#  'NETWORK SERVICE@C19312',
#  'SYSTEM@C16645',
#  'ANONYMOUS LOGON@C2734',
#  'U6377@DOM1',
#  'U321@DOM1',
#  'ANONYMOUS LOGON@C19717',
#  'ANONYMOUS LOGON@C19452',
#  'U8196@lanl.gov',
#  'LOCAL SERVICE@C17023',
#  'U9558@DOM1',
#  'ANONYMOUS LOGON@C10121',
#  'U4901@DOM9',
#  'U4743@?',
#  'ANONYMOUS LOGON@C1096',
#  'NETWORK SERVICE@C4812',
#  'ANONYMOUS LOGON@C11410',
#  'ANONYMOUS LOGON@C1725',
#  'U45@C1504',
#  'U367@DOM1',
#  'U6323@C2660',
#  'U10385@DOM1',
#  'U12320@DOM1',
#  'U11307@DOM1',
#  'ANONYMOUS LOGON@C10709',
#  'U35@C26133',
#  'ANONYMOUS LOGON@C21380',
#  'U7835@DOM1',
#  'ANONYMOUS LOGON@C1020',
#  'U1522@DOM1',
#  'U5505@DOM1',
#  'NETWORK SERVICE@C2719',
#  'ANONYMOUS LOGON@C23195',
#  'U11959@C3131',
#  'U7442@?',
#  'U11084@DOM1',
#  'ANONYMOUS LOGON@C8633',
#  'SYSTEM@C1096',
#  'SYSTEM@C14319',
#  'ANONYMOUS LOGON@C19945',
#  'SYSTEM@C9544',
#  'U8351@?',
#  'U1534@C25071',
#  'SYSTEM@C318',
#  'SYSTEM@C1368',
#  'U7081@DOM1',
#  'U8026@?',
#  'ANONYMOUS LOGON@C1991',
#  'SYSTEM@C21736',
#  'U4385@DOM1',
#  'ANONYMOUS LOGON@C6427',
#  'U4430@DOM1',
#  'ANONYMOUS LOGON@C4448',
#  'U2539@DOM1',
#  'LOCAL SERVICE@C18835',
#  'U10440@DOM1',
#  'U3269@DOM1',
#  'NETWORK SERVICE@C2922',
#  'ANONYMOUS LOGON@C16854',
#  'ANONYMOUS LOGON@C13740',
#  'U8982@DOM1',
#  'NETWORK SERVICE@C8822',
#  'SYSTEM@C20597',
#  'SYSTEM@C21394',
#  'SYSTEM@C3520',
#  'ANONYMOUS LOGON@C9516',
#  'SYSTEM@C5339',
#  'U11612@DOM1',
#  'U10018@DOM9',
#  'ANONYMOUS LOGON@C20384',
#  'U10215@?',
#  'U6818@DOM31',
#  'ANONYMOUS LOGON@C1863',
#  'U8469@lanl.gov',
#  'U3926@DOM1',
#  'U1621@?',
#  'U1916@C6328',
#  'ANONYMOUS LOGON@C9643',
#  'NETWORK SERVICE@C11918',
#  'NETWORK SERVICE@C3631',
#  'SYSTEM@C20732',
#  'U3275@?',
#  'U10883@C11190',
#  'LOCAL SERVICE@C6146',
#  'ANONYMOUS LOGON@C421',
#  'U10376@lanl.gov',
#  'U2123@?',
#  'SYSTEM@C9764',
#  'U3655@?',
#  'SYSTEM@C19507',
#  'U10656@DOM5',
#  'ANONYMOUS LOGON@C21751',
#  'SYSTEM@C26388',
#  'ANONYMOUS LOGON@C18462',
#  'U137@C2359',
#  'ANONYMOUS LOGON@C9741',
#  'U3363@DOM1',
#  'SYSTEM@C343',
#  'U8539@DOM1',
#  'U8599@?',
#  'U2875@DOM1',
#  'SYSTEM@C10185',
#  'LOCAL SERVICE@C22902',
#  'SYSTEM@C3761',
#  'SYSTEM@C23259',
#  'SYSTEM@C339',
#  'U11362@C24417',
#  'LOCAL SERVICE@C17400',
#  'NETWORK SERVICE@C14102',
#  'ANONYMOUS LOGON@C7818',
#  'U884@DOM1',
#  'U2364@DOM1',
#  'SYSTEM@C11725',
#  'U12160@DOM1',
#  'SYSTEM@C11525',
#  'U3776@?',
#  'U7917@C2794',
#  'U11362@C24422',
#  'SYSTEM@C3264',
#  'ANONYMOUS LOGON@C15464',
#  'SYSTEM@C1188',
#  'U2361@?',
#  'ANONYMOUS LOGON@C17654',
#  'SYSTEM@C18398',
#  'U9202@?',
#  'LOCAL SERVICE@C4556',
#  'LOCAL SERVICE@C3765',
#  'U2969@DOM1',
#  'NETWORK SERVICE@C18148',
#  'ANONYMOUS LOGON@C17322',
#  'U6729@?',
#  'U1718@C26641',
#  'U8756@?',
#  'U195@?',
#  'U6590@DOM9',
#  'NETWORK SERVICE@C26693',
#  'ANONYMOUS LOGON@C20212',
#  'SYSTEM@C19477',
#  'U425@C2886',
#  'SYSTEM@C14047',
#  'U7207@?',
#  'SYSTEM@C3486',
#  'SYSTEM@C6544',
#  'U1907@DOM9',
#  'SYSTEM@C16888',
#  'ANONYMOUS LOGON@C7125',
#  'U4018@?',
#  'ANONYMOUS LOGON@C8895',
#  'ANONYMOUS LOGON@C20179',
#  'U5204@DOM9',
#  'U6519@DOM1',
#  'ANONYMOUS LOGON@C22477',
#  'NETWORK SERVICE@C3780',
#  'ANONYMOUS LOGON@C6570',
#  'U12135@?',
#  'NETWORK SERVICE@C9613',
#  'SYSTEM@C955',
#  'U120@DOM9',
#  'SYSTEM@C15013',
#  'U96@C24526',
#  'LOCAL SERVICE@C3031',
#  'U10003@DOM148',
#  'U7324@DOM1',
#  'U151@DOM169',
#  'SYSTEM@C24042',
#  'U5269@C3167',
#  'SYSTEM@C802',
#  'ANONYMOUS LOGON@C7533',
#  'ANONYMOUS LOGON@C10460',
#  'U6351@DOM1',
#  'SYSTEM@C10585',
#  'ANONYMOUS LOGON@C12705',
#  'U8627@C17956',
#  'SYSTEM@C22999',
#  'U6790@?',
#  'U8393@?',
#  'SYSTEM@C23077',
#  'ANONYMOUS LOGON@C1563',
#  'U6032@?',
#  'ANONYMOUS LOGON@C16567',
#  'SYSTEM@C24212',
#  'U12043@C131',
#  'U7844@?',
#  'U11792@1937',
#  'U7024@DOM9',
#  'U7686@?',
#  'ANONYMOUS LOGON@C27066',
#  'U6302@DOM1',
#  'U6601@DOM1',
#  'U5845@?',
#  'U1425@DOM1',
#  'U9087@?',
#  'U8033@DOM9',
#  'U1641@DOM1',
#  'U11673@DOM9',
#  'ANONYMOUS LOGON@C18240',
#  'U7480@?',
#  'ANONYMOUS LOGON@C12343',
#  'U2050@C92',
#  'SYSTEM@C15636',
#  'U7546@?',
#  'SYSTEM@C4116',
#  'U6776@DOM1',
#  'SYSTEM@C9627',
#  'LOCAL SERVICE@C21000',
#  'SYSTEM@C16422',
#  'NETWORK SERVICE@C18605',
#  'U7206@C5416',
#  'NETWORK SERVICE@C3473',
#  'ANONYMOUS LOGON@C23077',
#  'ANONYMOUS LOGON@C5814',
#  'SYSTEM@C1667',
#  'NETWORK SERVICE@C2021',
#  'U9432@?',
#  'U1886@DOM1',
#  'LOCAL SERVICE@C4396',
#  'U3625@DOM9',
#  'U9531@?',
#  'U5649@?',
#  'U2916@?',
#  'ANONYMOUS LOGON@C18872',
#  'U2753@?',
#  'SYSTEM@C22462',
#  'U9747@DOM1',
#  'U1100@?',
#  'U1075@DOM21',
#  'SYSTEM@C14220',
#  'SYSTEM@C21542',
#  'U5577@DOM1',
#  'U7597@?',
#  'U3135@?',
#  'SYSTEM@C15421',
#  'U3607@?',
#  'U10839@DOM1',
#  'ANONYMOUS LOGON@C12755',
#  'SYSTEM@C12566',
#  'NETWORK SERVICE@C2952',
#  'SYSTEM@C24733',
#  'ANONYMOUS LOGON@C629',
#  'U3403@?',
#  'U7714@DOM1',
#  'U6560@?',
#  'U9830@DOM1',
#  'U9335@DOM1',
#  'ANONYMOUS LOGON@C14951',
#  'NETWORK SERVICE@C7499',
#  'NETWORK SERVICE@C18028',
#  'ANONYMOUS LOGON@C9508',
#  'U966@?',
#  'LOCAL SERVICE@C15982',
#  'ANONYMOUS LOGON@C21429',
#  'U2376@DOM9',
#  'U1718@C2519',
#  'SYSTEM@C7312',
#  'SYSTEM@C3450',
#  'ANONYMOUS LOGON@C14997',
#  'NETWORK SERVICE@C3688',
#  'U2718@DOM21',
#  'ANONYMOUS LOGON@C16969',
#  'SYSTEM@C7493',
#  'ANONYMOUS LOGON@C18353',
#  'U4665@DOM1',
#  'NETWORK SERVICE@C9518',
#  'SYSTEM@C9768',
#  'U9127@?',
#  'LOCAL SERVICE@C5309',
#  'U6619@?',
#  'SYSTEM@C7081',
#  'U7363@C18238',
#  'U1053@DOM1',
#  'ANONYMOUS LOGON@C10401',
#  'ANONYMOUS LOGON@C6887',
#  'U11025@?',
#  'SYSTEM@C4827',
#  'SYSTEM@C4434',
#  'ANONYMOUS LOGON@C12582',
#  'U4114@DOM1',
#  'ANONYMOUS LOGON@C14319',
#  'U4412@DOM9',
#  'U8005@?',
#  'U4351@DOM1',
#  'ANONYMOUS LOGON@C4013',
#  'U4628@DOM1',
#  'ANONYMOUS LOGON@C264',
#  'SYSTEM@C10976',
#  'SYSTEM@C13209',
#  'U6790@DOM1',
#  'SYSTEM@C12292',
#  'NETWORK SERVICE@C3295',
#  'SYSTEM@C20797',
#  'U7196@DOM9',
#  'SYSTEM@C6267',
#  'U4499@DOM1',
#  'U1076@C5406',
#  'U4750@?',
#  'ANONYMOUS LOGON@C8322',
#  'U4793@DOM1',
#  'NETWORK SERVICE@C16132',
#  'U10468@C23208',
#  'ANONYMOUS LOGON@C34',
#  'NETWORK SERVICE@C3984',
#  'U1224@?',
#  'SYSTEM@C998',
#  'U357@C12897',
#  'U730@?',
#  'U2387@DOM1',
#  'U1241@DOM9',
#  'U10308@C21844',
#  'U3284@DOM1',
#  'ANONYMOUS LOGON@C10291',
#  'U6760@?',
#  'U1924@?',
#  'U4381@?',
#  'ANONYMOUS LOGON@C22272',
#  'U2203@DOM1',
#  'U11575@C2833',
#  'U9887@DOM1',
#  'U5551@DOM1',
#  'ANONYMOUS LOGON@C4253',
#  'U7565@DOM1',
#  'ANONYMOUS LOGON@C6767',
#  'U9360@DOM9',
#  'LOCAL SERVICE@C21139',
#  'U2836@DOM1',
#  'U10164@DOM1',
#  'SYSTEM@C22434',
#  'SYSTEM@C5313',
#  'ANONYMOUS LOGON@C1717',
#  'U11067@DOM1',
#  'ANONYMOUS LOGON@C3402',
#  'ANONYMOUS LOGON@C6761',
#  'ANONYMOUS LOGON@C5111',
#  'ANONYMOUS LOGON@C20501',
#  ...]

# %%
df.select('success/failure').unique().collect()
# Out:
# shape: (2, 1)
# ┌─────────────────┐
# │ success/failure │
# │ ---             │
# │ str             │
# ╞═════════════════╡
# │ Fail            │
# │ Success         │
# └─────────────────┘

# %%
df.filter((pl.col('source_user@domain').is_in(machine_users)) & (pl.col('success/failure') == 'Fail')).collect().head()
# Out:
# shape: (5, 10)
# ┌──────┬────────────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ time ┆ source_use ┆ destinatio ┆ source_com ┆ … ┆ logon_type ┆ authentic ┆ success/f ┆ hash      │
# │ ---  ┆ r@domain   ┆ n_user@dom ┆ puter      ┆   ┆ ---        ┆ ation_ori ┆ ailure    ┆ ---       │
# │ str  ┆ ---        ┆ ain        ┆ ---        ┆   ┆ str        ┆ entation  ┆ ---       ┆ u64       │
# │      ┆ str        ┆ ---        ┆ str        ┆   ┆            ┆ ---       ┆ str       ┆           │
# │      ┆            ┆ str        ┆            ┆   ┆            ┆ str       ┆           ┆           │
# ╞══════╪════════════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 4    ┆ C1149$@DOM ┆ U1325@DOM1 ┆ C1149      ┆ … ┆ Batch      ┆ LogOn     ┆ Fail      ┆ 148342761 │
# │      ┆ 1          ┆            ┆            ┆   ┆            ┆           ┆           ┆ 150380659 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆           ┆ 87        │
# │ 5    ┆ C1846$@DOM ┆ U86@DOM1   ┆ C1846      ┆ … ┆ Batch      ┆ LogOn     ┆ Fail      ┆ 431929138 │
# │      ┆ 1          ┆            ┆            ┆   ┆            ┆           ┆           ┆ 087994179 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆           ┆ 3         │
# │ 6    ┆ C3073$@DOM ┆ C3073$@DOM ┆ C3073      ┆ … ┆ ?          ┆ TGT       ┆ Fail      ┆ 113970607 │
# │      ┆ 1          ┆ 1          ┆            ┆   ┆            ┆           ┆           ┆ 32021792  │
# │ 8    ┆ C1654$@DOM ┆ U86@DOM1   ┆ C1654      ┆ … ┆ Batch      ┆ LogOn     ┆ Fail      ┆ 128242313 │
# │      ┆ 1          ┆            ┆            ┆   ┆            ┆           ┆           ┆ 776756364 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆           ┆ 4         │
# │ 33   ┆ C2096$@?   ┆ C2096$@?   ┆ C457       ┆ … ┆ ?          ┆ TGT       ┆ Fail      ┆ 542622169 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆           ┆ 800221022 │
# │      ┆            ┆            ┆            ┆   ┆            ┆           ┆           ┆ 1         │
# └──────┴────────────┴────────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
# 
df2 = df.with_columns(
    pl.col('source_user@domain').is_in(human_users).alias('human_source')
    ).with_columns(pl.col('destination_user@domain').is_in(human_users).alias('human_destination')
    ).group_by(['human_source', 'human_destination', 'success/failure']).len().collect()

# %%
df2.sort(by='len', descending=True)
# Out:
# shape: (8, 4)
# ┌──────────────┬───────────────────┬─────────────────┬───────────┐
# │ human_source ┆ human_destination ┆ success/failure ┆ len       │
# │ ---          ┆ ---               ┆ ---             ┆ ---       │
# │ bool         ┆ bool              ┆ str             ┆ u32       │
# ╞══════════════╪═══════════════════╪═════════════════╪═══════════╡
# │ false        ┆ false             ┆ Success         ┆ 620471152 │
# │ true         ┆ true              ┆ Success         ┆ 405198267 │
# │ true         ┆ true              ┆ Fail            ┆ 9835150   │
# │ false        ┆ true              ┆ Success         ┆ 9722909   │
# │ true         ┆ false             ┆ Success         ┆ 3197823   │
# │ false        ┆ false             ┆ Fail            ┆ 2724811   │
# │ false        ┆ true              ┆ Fail            ┆ 274631    │
# │ true         ┆ false             ┆ Fail            ┆ 5716      │
# └──────────────┴───────────────────┴─────────────────┴───────────┘

# %%
df2.with_columns((pl.col('len') / pl.col('len').sum().over(['human_source', 'human_destination'])).alias('pct_sucess')).filter(
    pl.col('success/failure') == 'Success').sort(by='pct_sucess', descending=True).rename({'len' : 'Number_Successes'})
# Out:
# shape: (4, 5)
# ┌──────────────┬───────────────────┬─────────────────┬──────────────────┬────────────┐
# │ human_source ┆ human_destination ┆ success/failure ┆ Number_Successes ┆ pct_sucess │
# │ ---          ┆ ---               ┆ ---             ┆ ---              ┆ ---        │
# │ bool         ┆ bool              ┆ str             ┆ u32              ┆ f64        │
# ╞══════════════╪═══════════════════╪═════════════════╪══════════════════╪════════════╡
# │ true         ┆ false             ┆ Success         ┆ 3197823          ┆ 0.998216   │
# │ false        ┆ false             ┆ Success         ┆ 620471152        ┆ 0.995628   │
# │ true         ┆ true              ┆ Success         ┆ 405198267        ┆ 0.976303   │
# │ false        ┆ true              ┆ Success         ┆ 9722909          ┆ 0.97253    │
# └──────────────┴───────────────────┴─────────────────┴──────────────────┴────────────┘

# %%
# How often does a user talk to itself
df.filter(
    (pl.col('source_user@domain') == pl.col('destination_user@domain'))).group_by('human_source').len().collect()
# Out:
# shape: (2, 2)
# ┌──────────────┬───────────┐
# │ human_source ┆ len       │
# │ ---          ┆ ---       │
# │ bool         ┆ u32       │
# ╞══════════════╪═══════════╡
# │ false        ┆ 622983269 │
# │ true         ┆ 411559302 │
# └──────────────┴───────────┘

# %%
# Key metrics for human and machine users mean median variance etc

# %% [markdown]
# ### Checking the variance in flows over time

# %%
# Random sampled user plot

def sample_user(machine):
    """
    Samples a machine or human user and returns interaction times
    """
    if machine == True:
        user_number = np.random.randint(0, len(machine_users))
        user = machine_users[user_number]
    else:
        user_number = np.random.randint(0, len(human_users))
        user = human_users[user_number]

    user_frame = df.filter(pl.col('source_user@domain') == user).collect()
    times = user_frame.select('time').to_series().to_list()
    times = [int(t) for t in times]
    return user_frame, times

# %%
def plot_times(times, xlim, vert_line = None):
    fig, ax = plt.subplots(figsize=(12, 2))
    ax.eventplot(times, orientation="horizontal")
    ax.set_yticks([])
    ax.set_xlabel("Time")
    ax.set_xlim(0, xlim)
    if vert_line is not None:
        offset = vert_line[0]
        step = vert_line[1]
        for x in range(0, xlim, step):
            ax.axvline(x-offset, color="red", linewidth=0.8, alpha=0.6)
    plt.show()

# %%
# Sample a new set of machine times
_, times = sample_user(machine=False)
print(len(times))
# Out:
# 22460

# %%
# Max time in df is 5011199

v = None
v = (50000, 70000)
xlim = 100000
plot_times(times, xlim = xlim, vert_line=v)

# %%
# Random sampled machines flow plot and variance
df.head().collect()
# Out:
# shape: (5, 9)
# ┌──────┬────────────┬────────────┬────────────┬───┬────────────┬───────────┬───────────┬───────────┐
# │ time ┆ source_use ┆ destinatio ┆ source_com ┆ … ┆ authentica ┆ logon_typ ┆ authentic ┆ success/f │
# │ ---  ┆ r@domain   ┆ n_user@dom ┆ puter      ┆   ┆ tion_type  ┆ e         ┆ ation_ori ┆ ailure    │
# │ str  ┆ ---        ┆ ain        ┆ ---        ┆   ┆ ---        ┆ ---       ┆ entation  ┆ ---       │
# │      ┆ str        ┆ ---        ┆ str        ┆   ┆ str        ┆ str       ┆ ---       ┆ str       │
# │      ┆            ┆ str        ┆            ┆   ┆            ┆           ┆ str       ┆           │
# ╞══════╪════════════╪════════════╪════════════╪═══╪════════════╪═══════════╪═══════════╪═══════════╡
# │ 1    ┆ ANONYMOUS  ┆ ANONYMOUS  ┆ C1250      ┆ … ┆ NTLM       ┆ Network   ┆ LogOn     ┆ Success   │
# │      ┆ LOGON@C586 ┆ LOGON@C586 ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 1    ┆ ANONYMOUS  ┆ ANONYMOUS  ┆ C586       ┆ … ┆ ?          ┆ Network   ┆ LogOff    ┆ Success   │
# │      ┆ LOGON@C586 ┆ LOGON@C586 ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 1    ┆ C101$@DOM1 ┆ C101$@DOM1 ┆ C988       ┆ … ┆ ?          ┆ Network   ┆ LogOff    ┆ Success   │
# │ 1    ┆ C1020$@DOM ┆ SYSTEM@C10 ┆ C1020      ┆ … ┆ Negotiate  ┆ Service   ┆ LogOn     ┆ Success   │
# │      ┆ 1          ┆ 20         ┆            ┆   ┆            ┆           ┆           ┆           │
# │ 1    ┆ C1021$@DOM ┆ C1021$@DOM ┆ C1021      ┆ … ┆ Kerberos   ┆ Network   ┆ LogOn     ┆ Success   │
# │      ┆ 1          ┆ 1          ┆            ┆   ┆            ┆           ┆           ┆           │
# └──────┴────────────┴────────────┴────────────┴───┴────────────┴───────────┴───────────┴───────────┘

# %%
# Checking for duplicates
df.group_by(['time', 'source_user@domain', 'destination_user@domain', 'source_computer', 'destination_computer', 'authentication_type', 'logon_type', 'authentication_orientation', 'success/failure']).len().sort(by='len').head().collect()

# %% [markdown]
# ### Noteworthy findings
#
# #### Section 1
# No duplicates found
#
#
# Clear distinction between human and machine users in the dataframe dermakated by $
# Clear periodic behaviour observed for some machine users
# Multiple requests made within identical time periods common

# %% [markdown]
# #### Example of clearly regular machine behaviour
#
# ![Output plot](savedplots/machine_plot1.png)
# ![Output plot](savedplots/machine_plot2.png)

# %% [markdown]
# ### Typical examples of human behaviour
# Less regularity is typically observed
#
# ![Output plot](savedplots/human_user1.png)
# ![Output plot](savedplots/human_user2.png)

# %%
# Example of multiple requests in the same window
_.head()
# Out:
# shape: (5, 9)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ time    ┆ source_use ┆ destinati ┆ source_co ┆ … ┆ authentic ┆ logon_typ ┆ authentic ┆ success/f │
# │ ---     ┆ r@domain   ┆ on_user@d ┆ mputer    ┆   ┆ ation_typ ┆ e         ┆ ation_ori ┆ ailure    │
# │ str     ┆ ---        ┆ omain     ┆ ---       ┆   ┆ e         ┆ ---       ┆ entation  ┆ ---       │
# │         ┆ str        ┆ ---       ┆ str       ┆   ┆ ---       ┆ str       ┆ ---       ┆ str       │
# │         ┆            ┆ str       ┆           ┆   ┆ str       ┆           ┆ str       ┆           │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1422360 ┆ C23653$@DO ┆ C23653$@D ┆ C23653    ┆ … ┆ ?         ┆ ?         ┆ TGT       ┆ Success   │
# │         ┆ M1         ┆ OM1       ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1422360 ┆ C23653$@DO ┆ C23653$@D ┆ C23653    ┆ … ┆ ?         ┆ ?         ┆ TGS       ┆ Success   │
# │         ┆ M1         ┆ OM1       ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1422360 ┆ C23653$@DO ┆ C23653$@D ┆ C23653    ┆ … ┆ Kerberos  ┆ Network   ┆ LogOn     ┆ Success   │
# │         ┆ M1         ┆ OM1       ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1422360 ┆ C23653$@DO ┆ C23653$@D ┆ C23653    ┆ … ┆ ?         ┆ ?         ┆ TGS       ┆ Success   │
# │         ┆ M1         ┆ OM1       ┆           ┆   ┆           ┆           ┆           ┆           │
# │ 1422371 ┆ C23653$@DO ┆ C23653$@D ┆ C528      ┆ … ┆ ?         ┆ Network   ┆ LogOff    ┆ Success   │
# │         ┆ M1         ┆ OM1       ┆           ┆   ┆           ┆           ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# ### A note on domains, machines and system processes
#
# Domains are basically big databases of usernames and passwords and permissions on a windows server. You authenticate against the domain and then are granted permissions to do stuff by the domain controler.
#
# User activity is usually run with a user account.
#
# Computer accounts also exist and can be used by appications for running processes automated and not.
#
# Windows also provides some built in accounts which can be harnessed by applications. These are the system accounts the domain here is the machine the system account is running on.
#
# Anonymous logons are sessions where Windows did not associate the connection with a named authenticated identity. The underlying actor could be a user process, machine process, system process, or misconfigured service.

# %% [markdown]
# ### Cleaning + Pipeline to do
#
# - Filter the anon users as these can correspond to many different types of behaviour
# - Maybe filter the system users out too
# - Operate on a user not a computer level as multiple different users can share the same machine making messy behaviour on a machine level with mixture between human and machine time series observed.
# - For each user, we estimate a mean and variance for every bin. These estimates are then smoothed towards cluster-average values. We first sort each user’s bin-level parameters to form a user-specific distribution. We then build a cluster-level reference distribution by averaging parameters at the same sorted position across users in the cluster. Each user’s parameter is then smoothed towards the corresponding value in this cluster distribution.
